# %% [markdown]
# # **PANDAS**

# %%
import pandas as pd

# %%
# Used for Reading the file
my_file = pd.read_csv("datasets/Used_Bikes.csv") 

# Used to store the file into a dataframe
df = pd.DataFrame(my_file)

# %%
# Provides first five values by default
df.head(7)
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                      Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6         Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha
# 5  First Owner  6.0  150.0         Yamaha
# 6  First Owner  3.0  160.0          Honda

# %%
# Provides last five values by default
df.tail(7)
# Out:
#                        bike_name    price         city  kms_driven  \
# 32641        Bajaj Avenger 220cc  41000.0        Delhi     20245.0
# 32642         Hero Passion 100cc  15000.0  Perumbavoor     35000.0
# 32643     Hero Passion Pro 100cc  39000.0        Delhi     22000.0
# 32644       TVS Apache RTR 180cc  30000.0       Karnal      6639.0
# 32645   Bajaj Avenger Street 220  60000.0        Delhi     20373.0
# 32646  Hero Super Splendor 125cc  15600.0       Jaipur     84186.0
# 32647         Bajaj Pulsar 150cc  22000.0         Pune     60857.0
#
#               owner   age  power  brand
# 32641  Second Owner  11.0  220.0  Bajaj
# 32642  Second Owner  19.0  100.0   Hero
# 32643   First Owner   4.0  100.0   Hero
# 32644   First Owner   9.0  180.0    TVS
# 32645   First Owner   6.0  220.0  Bajaj
# 32646   First Owner  16.0  125.0   Hero
# 32647   First Owner  13.0  150.0  Bajaj

# %%
# Gives the Information of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
# Gives the Descriptive Statistics
df.describe()
# Out:
#               price     kms_driven           age         power
# count  3.264800e+04   32648.000000  32648.000000  32648.000000
# mean   6.829542e+04   26344.625184      8.048211    213.511302
# std    9.071860e+04   22208.527695      4.031700    134.428868
# min    4.400000e+03       1.000000      1.000000    100.000000
# 25%    2.500000e+04   12000.000000      5.000000    150.000000
# 50%    4.300000e+04   20373.000000      7.000000    150.000000
# 75%    8.000000e+04   35000.000000     10.000000    220.000000
# max    1.900000e+06  750000.000000     63.000000   1800.000000

# %%
# Gives the Datatype of each column
print(df.dtypes)

# Gives the shape of the dataframe
print("Shape : ", df.shape)
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object
# Shape :  (32648, 8)

# %%
# Gives the values of a particular column
brand_name_df = df["brand"]

# Gives the unique values
print(brand_name_df.unique())

# Gives the number of unique values
print("Number of unique values : ", brand_name_df.nunique())
# Out:
# ['TVS' 'Royal Enfield' 'Triumph' 'Yamaha' 'Honda' 'Hero' 'Bajaj' 'Suzuki'
#  'Benelli' 'KTM' 'Mahindra' 'Kawasaki' 'Ducati' 'Hyosung'
#  'Harley-Davidson' 'Jawa' 'BMW' 'Indian' 'Rajdoot' 'LML' 'Yezdi' 'MV'
#  'Ideal']
# Number of unique values :  23

# %%
bike_name_df = df["bike_name"]
print("Number of unique values : ", bike_name_df.nunique())
# Out:
# Number of unique values :  471

# %%
# Gives the rows for a given range
df.iloc[0:5]
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
# Check if their is a value which is null or not
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
# Check if their is a duplicate or not
print(df.duplicated().sum())
# Out:
# 25324

# %%
# Delete the duplicates
my_file.drop_duplicates(inplace=True)

print(my_file.duplicated().sum())
# Out:
# 0

# %%
# Delete the null values
my_file.dropna(inplace=True)

# Check all the null values and returns their sum
my_file.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
# Used to checks duplicates in a specific column
print(my_file["brand"].duplicated().sum())
# Out:
# 7301

# %%
# Used to fill null values
df.fillna(0)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
# Used to find the mean of all the values
print(df['price'].mean())

# In price fills the null values with mean of all the prices 
df["price"].fillna(df['price'].mean())
# Out:
# 68295.41763660868
# 0         35000.0
# 1        119900.0
# 2        600000.0
# 3         65000.0
# 4         80000.0
#            ...
# 32643     39000.0
# 32644     30000.0
# 32645     60000.0
# 32646     15600.0
# 32647     22000.0
# Name: price, Length: 32648, dtype: float64

# %%
# Used to rename the column
my_file.rename(columns={"kms_driven":"km_driven"},inplace=True)

# %%
# Prints all the column
print(my_file.columns)
df.head()
# Out:
# Index(['bike_name', 'price', 'city', 'km_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
# Used to Sort the inde of the table as per the given command
my_file.sort_index(ascending=False)
# Out:
#                                  bike_name     price       city  km_driven  \
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad     7127.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad    21300.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur     3430.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore    60000.0
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi    48587.0
# ...                                    ...       ...        ...        ...
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore    10000.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore    16329.0
# 2                     Triumph Daytona 675R  600000.0      Delhi      110.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi    11000.0
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad    17654.0
#
#             owner  age  power            brand
# ...

# %%
# Used to find the datatype
my_file.select_dtypes(exclude='O')
# Out:
#          price  km_driven  age  power
# 0      35000.0    17654.0  3.0  110.0
# 1     119900.0    11000.0  4.0  350.0
# 2     600000.0      110.0  8.0  675.0
# 3      65000.0    16329.0  4.0  180.0
# 4      80000.0    10000.0  3.0  150.0
# ...        ...        ...  ...    ...
# 9362   25000.0    48587.0  8.0  150.0
# 9369   35000.0    60000.0  9.0  220.0
# 9370  450000.0     3430.0  4.0  750.0
# 9371  139000.0    21300.0  4.0  400.0
# 9372   80000.0     7127.0  5.0  220.0
#
# [7324 rows x 4 columns]
